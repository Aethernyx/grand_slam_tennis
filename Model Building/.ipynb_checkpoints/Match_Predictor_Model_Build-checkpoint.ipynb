# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# %%
match_data = '../Data/Updated_Data.csv'

# %%
matches = pd.read_csv(match_data)

matches.drop('Unnamed: 0', axis=1, inplace=True)

men_matches = matches[matches['players_gender'] == 'M']

women_matches = matches[matches['players_gender'] == 'W']
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3050: DtypeWarning: Columns (3,5,6,7,9,10,11,12,13,66,68,69,73,74,75,77) have mixed types. Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
input_features = ['p1_ace', 'p2_ace', 'p1_shot_winner', 'p2_shot_winner', 'p1_double_fault', 
                                'p2_double_fault', 'p1_unforced_error', 'p2_unforced_error', 'p1_net_point_won', 
                                'p2_net_point_won', 'p1_break_point_won', 'p2_break_point_won', 'p1_first_serve_in', 
                                'p2_first_serve_in', 'p1_first_serve_won', 'p2_first_serve_won', 'p1_second_serve_in',
                                'p2_second_serve_in', 'p1_second_serve_won', 'p2_second_serve_won', 'p1_forced_error'
                                , 'p2_forced_error']

men_matches.dropna(subset=input_features, inplace=True)

women_matches.dropna(subset=input_features, inplace=True)
# Out:
# <ipython-input-4-0d723ceddaef>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   men_matches.dropna(subset=input_features, inplace=True)
# <ipython-input-4-0d723ceddaef>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   women_matches.dropna(subset=input_features, inplace=True)

# %%
#men_matches_2011 = men_matches[men_matches['match_year'] == 2011]

#women_matches_2011 = women_matches[women_matches['match_year'] == 2011]

# %%
pd.set_option('display.max_columns', 101)
pd.set_option('display.max_rows', 250)

# %%
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1101', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1104', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1105', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1106', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1108', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1109', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1111', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1112', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1113', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1116', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1117', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1119', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1121', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1124', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1125', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1129', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1131', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1132', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1133', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1134', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1135', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1136', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1137', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1139', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1140', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1141', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1143', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1144', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1147', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1148', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1149', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1150', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1152', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1153', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1154', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1156', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1157', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1159', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1161', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1162', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1163', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1164', 'match_winner'] = 'player_2'

men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1201', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1202', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1203', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1204', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1205', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1206', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1207', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1208', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1209', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1210', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1210', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1211', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1212', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1214', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1216', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1218', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1219', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1220', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1221', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1222', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1223', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1224', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1225', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1228', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1229', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1230', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1230', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1231', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1232', 'match_winner'] = 'player_2'

men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1301', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1302', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1303', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1304', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1305', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1306', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1307', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1308', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1309', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1310', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1311', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1312', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1313', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1314', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1315', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1316', 'match_winner'] = 'player_2'

men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1401', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1402', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1403', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1404', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1405', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1406', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1407', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1408', 'match_winner'] = 'player_2'

men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1501', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1502', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1503', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1601', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1602', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-frenchopen-1701', 'match_winner'] = 'player_1'

men_matches.loc[men_matches['match_id'] == '2011-usopen-1101', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1108', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1109', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1116', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1117', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1120', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1123', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1124', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1125', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1128', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1132', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1132', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1133', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1134', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1135', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1136', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1137', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1140', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1142', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1144', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1145', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1148', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1149', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1150', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1152', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1153', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1154', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1156', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1157', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1162', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1164', 'match_winner'] = 'player_2'

men_matches.loc[men_matches['match_id'] == '2011-usopen-1201', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1204', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1205', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1206', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1208', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1209', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1210', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1211', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1212', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1213', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1214', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1216', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1217', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1218', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1219', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1220', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1221', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1224', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1225', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1226', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1227', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1228', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1231', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1232', 'match_winner'] = 'player_2'

men_matches.loc[men_matches['match_id'] == '2011-usopen-1301', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1302', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1303', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1304', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1305', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1306', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1307', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1308', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1309', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1310', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1311', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1312', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1313', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1314', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1315', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1316', 'match_winner'] = 'player_2'

men_matches.loc[men_matches['match_id'] == '2011-usopen-1401', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1402', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1403', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1404', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1406', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1407', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1408', 'match_winner'] = 'player_2'

men_matches.loc[men_matches['match_id'] == '2011-usopen-1501', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1502', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1503', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1504', 'match_winner'] = 'player_2'

men_matches.loc[men_matches['match_id'] == '2011-usopen-1601', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-usopen-1602', 'match_winner'] = 'player_2'

men_matches.loc[men_matches['match_id'] == '2011-usopen-1701', 'match_winner'] = 'player_1'


men_matches.loc[men_matches['match_id'] == '011-wimbledon-1105', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '011-wimbledon-1112', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '011-wimbledon-1117', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '011-wimbledon-1120', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '011-wimbledon-1128', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '011-wimbledon-1132', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '011-wimbledon-1133', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '011-wimbledon-1142', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '011-wimbledon-1148', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '011-wimbledon-1149', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '011-wimbledon-1150', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '011-wimbledon-1155', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '011-wimbledon-1160', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '011-wimbledon-1161', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '011-wimbledon-1164', 'match_winner'] = 'player_2'

men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1201', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1202', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1203', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1205', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1206', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1208', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1209', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1211', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1212', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1216', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1217', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1220', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1221', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1223', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1224', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1225', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1226', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1228', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1229', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1231', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1232', 'match_winner'] = 'player_2'

men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1301', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1302', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1304', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1305', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1307', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1308', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1309', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1310', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1311', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1312', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1313', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1314', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1316', 'match_winner'] = 'player_2'

men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1401', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1402', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1403', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1404', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1405', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1406', 'match_winner'] = 'player_2'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1407', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1408', 'match_winner'] = 'player_2'

men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1501', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1502', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1503', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1504', 'match_winner'] = 'player_2'

men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1601', 'match_winner'] = 'player_1'
men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1602', 'match_winner'] = 'player_2'

men_matches.loc[men_matches['match_id'] == '2011-wimbledon-1701', 'match_winner'] = 'player_2'
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
men_matches = pd.get_dummies(men_matches, columns=['match_winner'], drop_first=True)

# %%
men_matches_avg = men_matches.groupby('match_id')[input_features].mean().reset_index()

men_matches_sums = men_matches.groupby('match_id')[input_features].sum().reset_index()

# %%
men_matches_features = men_matches_sums

men_matches_features['p1_net_point_won'] = men_matches_avg['p1_net_point_won']
men_matches_features['p2_net_point_won'] = men_matches_avg['p2_net_point_won']

men_matches_features['p1_break_point_won'] = men_matches_avg['p1_break_point_won']
men_matches_features['p2_break_point_won'] = men_matches_avg['p2_break_point_won']

men_matches_features['p1_first_serve_in'] = men_matches_avg['p1_first_serve_in']
men_matches_features['p2_first_serve_in'] = men_matches_avg['p2_first_serve_in']
men_matches_features['p1_first_serve_won'] = men_matches_avg['p1_first_serve_won']
men_matches_features['p2_first_serve_won'] = men_matches_avg['p2_first_serve_won']

men_matches_features['p1_second_serve_in'] = men_matches_avg['p1_second_serve_in']
men_matches_features['p2_second_serve_in'] = men_matches_avg['p2_second_serve_in']
men_matches_features['p1_second_serve_won'] = men_matches_avg['p1_second_serve_won']
men_matches_features['p2_second_serve_won'] = men_matches_avg['p2_second_serve_won']

men_matches_features['match_winner'] = men_matches.\
groupby('match_id')['match_winner_player_2'].last().reset_index()['match_winner_player_2']

men_matches_features.head()
# Out:
#                match_id  p1_ace  p2_ace  p1_shot_winner  p2_shot_winner  \
# 0  2011-frenchopen-1101     8.0    13.0            50.0            54.0
# 1  2011-frenchopen-1104     0.0     4.0            22.0            27.0
# 2  2011-frenchopen-1105    12.0     7.0            36.0            32.0
# 3  2011-frenchopen-1106    10.0     4.0            40.0            23.0
# 4  2011-frenchopen-1108     0.0     7.0            20.0            60.0
#
#    p1_double_fault  p2_double_fault  p1_unforced_error  p2_unforced_error  \
# 0              1.0              3.0               27.0               58.0
# 1              0.0              3.0               35.0               24.0
# 2              5.0              4.0               24.0               35.0
# 3              0.0              1.0               34.0               20.0
# 4              2.0              9.0               42.0               64.0
#
#    p1_net_point_won  p2_net_point_won  p1_break_point_won  p2_break_point_won  \
# ...

# %%
men_matches_features.to_csv('men_match_features')

# %% [markdown]
# ## Model Building

# %%
X = men_matches_features.drop(['match_winner', 'match_id'], axis=1)
y = men_matches_features['match_winner']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

log_model = LogisticRegression(max_iter=250)

log_model.fit(X_train, y_train)

log_pred = log_model.predict(X_test)

log_proba = log_model.predict_proba(X_test)

print(classification_report(y_test, log_pred))
print(confusion_matrix(y_test, log_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96        37
#            1       0.97      0.95      0.96        38
#
#     accuracy                           0.96        75
#    macro avg       0.96      0.96      0.96        75
# weighted avg       0.96      0.96      0.96        75
#
# [[36  1]
#  [ 2 36]]

# %%
from sklearn.svm import SVC

svm_model = SVC(kernel='linear', probability=True)

svm_model.fit(X_train, y_train)

svm_pred = svm_model.predict(X_test)

svm_proba = svm_model.predict_proba(X_test)

print(classification_report(y_test, svm_pred))
print(confusion_matrix(y_test, svm_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        37
#            1       0.97      0.97      0.97        38
#
#     accuracy                           0.97        75
#    macro avg       0.97      0.97      0.97        75
# weighted avg       0.97      0.97      0.97        75
#
# [[36  1]
#  [ 1 37]]

# %%
from sklearn.ensemble import RandomForestClassifier

rfc_model = RandomForestClassifier()

rfc_model.fit(X_train, y_train)

rfc_pred = rfc_model.predict(X_test)

rfc_proba = rfc_model.predict_proba(X_test)

print(classification_report(y_test, rfc_pred))
print(confusion_matrix(y_test, rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        37
#            1       0.95      0.95      0.95        38
#
#     accuracy                           0.95        75
#    macro avg       0.95      0.95      0.95        75
# weighted avg       0.95      0.95      0.95        75
#
# [[35  2]
#  [ 2 36]]

# %%
import scikitplot as skplt

skplt.metrics.plot_roc_curve(y_test, log_proba, title='Logistic Regression ROC Curves')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; This will be removed in v0.5.0. Please use scikitplot.metrics.plot_roc instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
skplt.metrics.plot_roc_curve(y_test, svm_proba, title='Logistic Regression ROC Curves')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; This will be removed in v0.5.0. Please use scikitplot.metrics.plot_roc instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
skplt.metrics.plot_roc_curve(y_test, rfc_proba, title='Logistic Regression ROC Curves')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; This will be removed in v0.5.0. Please use scikitplot.metrics.plot_roc instead.
#   warnings.warn(msg, category=FutureWarning)
